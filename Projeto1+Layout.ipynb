# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Rodrigo Crespo
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# qual é o dispositivo mais utilizado em sao paulo para acessar a internet e qual tipo de coneccao é mais utilizada?

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
dados = pd.read_csv('DOM2015.csv',sep=',')
dados= pd.DataFrame(dados)
# Out:
# Esperamos trabalhar no diretório
# C:\Users\rod_c\Documents\GitHub\CD17\Projeto1

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')
dados_lido = dados.loc[:,['UF','V02323','V02324','V02325','V02326','V02327','V02424','V02425','V02426']]
dados_lido= dados_lido[pd.notnull(dados_lido.UF)&       pd.notnull(dados_lido.V02323)&                        pd.notnull(dados_lido.V02324)&                        pd.notnull(dados_lido.V02325)&                        pd.notnull(dados_lido.V02326)&  pd.notnull(dados_lido.V02327)&  pd.notnull(dados_lido.V02424)&  pd.notnull(dados_lido.V02425)& pd.notnull(dados_lido.V02426)]
dados_lido.to_csv('dados_prontos2015.csv')
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dados_2015 = pd.read_csv('dados_prontos2015.csv',sep=',')
dados_2015 = pd.DataFrame(dados_lido)
dados_2015.UF = dados.UF.astype('category')
dados_2015.V02323 = dados.V02323.astype('category')
dados_2015.V02324 = dados.V02324.astype('category')
dados_2015.V02325 = dados.V02325.astype('category')
dados_2015.V02326 = dados.V02326.astype('category')
dados_2015.V02327 = dados.V02327.astype('category')
dados_2015.V02424 = dados.V02424.astype('category')
dados_2015.V02425 = dados.V02425.astype('category')
dados_2015.V02426 = dados.V02426.astype('category')


dados_2015.UF.cat.categories = ("Rondonia","Acre","Amazonas","Roraima", \
"Pará","Amapá", "Tocantins", "Maranhão", "Piauí", "Ceará","Rio Grande do Norte","Paraíba", \
"Pernambuco","Alagoas","Sergipe","Bahia","Minas Gerais","Espírito Santo","Rio de Janeiro",\
"São Paulo","Paraná","Santa Catarina","Rio Grande do Sul","Mato Grosso do Sul","Mato Grosso","Goiás","Distrito Federal")



dados_2015.V02323.cat.categories = ('Sim','Não')
dados_2015.V02324.cat.categories = ('Sim','Não')
dados_2015.V02325.cat.categories = ('Sim','Não')
dados_2015.V02326.cat.categories = ('Sim','Não')
dados_2015.V02327.cat.categories = ('Sim','Não')
dados_2015.V02424.cat.categories = ('Sim','Não')
dados_2015.V02425.cat.categories = ('Sim','Não')
dados_2015.V02426.cat.categories = ('Sim','Não')
dados_2015.columns = ['UF','MICROCOMPUTADOR','CELULAR','TABLET','TV','OUTRO EQUIP','3G OU 4G','CONEXÃO DISCADA','BANDA LARGA']
dados_15 =dados_2015[dados_2015.UF == 'São Paulo']
dados_15
# Out:
#                UF MICROCOMPUTADOR CELULAR TABLET   TV OUTRO EQUIP 3G OU 4G  \
# 93132   São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 93133   São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 93135   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93140   São Paulo             Sim     Sim    Não  Não         Não      Não
# 93143   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93147   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93148   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93149   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93150   São Paulo             Sim     Não    Não  Não         Não      Não
# 93156   São Paulo             Não     Sim    Não  Não         Não      Sim
# 93157   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93160   São Paulo             Sim     Sim    Sim  Não         Não      Não
# 93161   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93167   São Paulo             Sim     Não    Não  Não         Não      Não
# 93171   São Paulo             Sim     Não    Não  Não         Não      Não
# 93172   São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 93173   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93175   São Paulo             Não     Sim    Não  Não         Não      Sim
# 93176   São Paulo             Não     Sim    Sim  Não         Não      Sim
# 93177   São Paulo             Não     Sim    Não  Não         Não      Sim
# 93178   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93179   São Paulo             Sim     Sim    Não  Não         Não      Sim
# 93182   São Paulo             Sim     Sim    Sim  Não         Não      Não
# 93184   São Paulo             Sim     Não    Não  Não         Não      Não
# 93186   São Paulo             Sim     Não    Não  Não         Não      Sim
# 93187   São Paulo             Sim     Sim    Não  Não         Não      Não
# 93190   São Paulo             Não     Sim    Não  Não         Não      Sim
# 93193   São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 93194   São Paulo             Não     Sim    Não  Não         Não      Sim
# 93195   São Paulo             Não     Sim    Não  Não         Não      Sim
# ...           ...             ...     ...    ...  ...         ...      ...
# 110369  São Paulo             Não     Sim    Não  Não         Não      Sim
# 110370  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110371  São Paulo             Não     Sim    Não  Não         Não      Sim
# 110376  São Paulo             Sim     Sim    Não  Sim         Não      Não
# 110381  São Paulo             Sim     Sim    Sim  Sim         Não      Não
# 110382  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110383  São Paulo             Não     Sim    Não  Não         Não      Sim
# 110384  São Paulo             Não     Sim    Não  Não         Não      Sim
# 110385  São Paulo             Sim     Sim    Não  Sim         Não      Sim
# 110386  São Paulo             Sim     Sim    Sim  Sim         Não      Sim
# 110387  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110390  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110393  São Paulo             Sim     Sim    Sim  Não         Sim      Sim
# 110398  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110400  São Paulo             Sim     Sim    Sim  Sim         Não      Sim
# 110401  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110403  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110404  São Paulo             Sim     Não    Sim  Não         Não      Sim
# 110405  São Paulo             Sim     Não    Não  Não         Não      Não
# 110408  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110409  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110410  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110411  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110412  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110414  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110415  São Paulo             Não     Sim    Não  Não         Não      Sim
# 110416  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110418  São Paulo             Sim     Sim    Sim  Não         Não      Sim
# 110420  São Paulo             Sim     Sim    Não  Não         Não      Sim
# 110421  São Paulo             Sim     Não    Sim  Não         Não      Sim
#
#        CONEXÃO DISCADA BANDA LARGA
# 93132              Não         Sim
# 93133              Não         Sim
# 93135              Não         Sim
# 93140              Não         Sim
# 93143              Não         Sim
# 93147              Não         Sim
# 93148              Não         Sim
# 93149              Não         Sim
# 93150              Não         Sim
# 93156              Não         Não
# 93157              Não         Sim
# 93160              Não         Sim
# 93161              Não         Sim
# 93167              Não         Sim
# 93171              Não         Sim
# 93172              Não         Sim
# 93173              Sim         Não
# 93175              Não         Não
# 93176              Não         Não
# 93177              Não         Não
# 93178              Não         Sim
# 93179              Não         Sim
# 93182              Não         Sim
# 93184              Não         Sim
# 93186              Não         Sim
# 93187              Não         Sim
# 93190              Não         Não
# 93193              Não         Sim
# 93194              Não         Não
# 93195              Não         Não
# ...                ...         ...
# 110369             Não         Sim
# 110370             Não         Sim
# 110371             Não         Não
# 110376             Não         Sim
# 110381             Não         Sim
# 110382             Não         Sim
# 110383             Não         Não
# 110384             Não         Não
# 110385             Não         Sim
# 110386             Não         Sim
# 110387             Não         Sim
# 110390             Não         Sim
# 110393             Não         Sim
# 110398             Não         Não
# 110400             Sim         Não
# 110401             Não         Sim
# 110403             Não         Sim
# 110404             Não         Não
# 110405             Não         Sim
# 110408             Sim         Sim
# 110409             Sim         Sim
# 110410             Sim         Sim
# 110411             Sim         Sim
# 110412             Sim         Sim
# 110414             Sim         Sim
# 110415             Sim         Sim
# 110416             Sim         Sim
# 110418             Sim         Sim
# 110420             Sim         Sim
# 110421             Sim         Sim
#
# [9613 rows x 9 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
